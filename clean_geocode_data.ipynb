# %%
import pandas as pd
import requests

# %% [markdown]
# ### Pull and filter data on Italy

# %%
path = 'data/winemag-data-130k-v2.csv'
df = pd.read_csv(path)

# %%
df.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
df = df[df['country']=='Italy']
df.head(1)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
s = ' winery'
df_wineries = sorted(df.winery.unique())
df_wineries = [i + s for i in df_wineries]
df_wineries
# Out:
# ['460 Casina Bric winery',
#  'A-Mano winery',
#  'Abbadia Ardenga winery',
#  'Abbazia Monte Oliveto winery',
#  'Abbazia Santa Anastasia winery',
#  'Abbazia di Novacella winery',
#  'Abbona Marziano winery',
#  'Abraxas winery',
#  'Accadia winery',
#  'Accordini Igino winery',
#  'Acinum winery',
#  'Ada Nada winery',
#  'Adalia winery',
#  'Adami winery',
#  'Adanti winery',
#  'Adria Vini winery',
#  'Adriano Marco & Vittorio winery',
#  'Ager Falernus winery',
#  'Agostina Pieri winery',
#  'Agostino Bosco winery',
#  'Agostino Pavia & Figli winery',
#  'Agostino Vicentini winery',
#  'Agricola Bellaria winery',
#  'Agricola Pace winery',
#  'Agricola Pugliano winery',
#  'Agricola Punica winery',
#  'Agricola Querciabella winery',
#  'Agricola Sulin winery',
#  'Agricola Tamburini winery',
#  'Agricole Vallone winery',
#  'Agricoltori del Chianti Geografico winery',
#  'Agrinatura winery',
#  'Agrisole winery',
#  'AgroArgento winery',
#  'Aia Vecchia winery',
# ...

# %%
#test_wineries_df = df_wineries[0:5]
test_wineries_df
# Out:
# ['460 Casina Bric winery',
#  'A-Mano winery',
#  'Abbadia Ardenga winery',
#  'Abbazia Monte Oliveto winery',
#  'Abbazia Santa Anastasia winery']

# %%
def geo_code_wineries(input_list):
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    api_key = 'AIzaSyDAdtFm1tgIgdVHpYdUzqCWlL2zzVKDjzs'

    latlong = []
    
    for name in input_list:
        params = {'key': api_key, 'address': name, 'components':'country:italy'}
        request = requests.get(url, params=params)
        results = request.json()['results']
        if results != []:
            location = results[0]['geometry']['location']
            lat = location['lat']
            long = location['lng']
            formatted_address = results[0]['formatted_address']
            latlong.append([name, lat, long, formatted_address])

    latlong_df = pd.DataFrame(data=latlong, columns=['name', 'lat', 'long', 'address'])
    
    return latlong_df

#https://maps.googleapis.com/maps/api/geocode/json?address=Winnetka&key=AIzaSyDAdtFm1tgIgdVHpYdUzqCWlL2zzVKDjzs

# %%
#latlong_df = geo_code_wineries(df_wineries)
# Out:
# 460 Casina Bric winery
# [{'address_components': [{'long_name': 'Barolo', 'short_name': 'Barolo', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Provincia di Cuneo', 'short_name': 'CN', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Italy', 'short_name': 'IT', 'types': ['country', 'political']}, {'long_name': '12060', 'short_name': '12060', 'types': ['postal_code']}], 'formatted_address': 'Via Sorello, Cascina Bricco Fraz. Vergne 12060 BAROLO (CN), 12060 Barolo CN, Italy', 'geometry': {'location': {'lat': 44.6182124, 'lng': 7.928459699999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 44.6195613802915, 'lng': 7.929808680291502}, 'southwest': {'lat': 44.6168634197085, 'lng': 7.927110719708498}}}, 'place_id': 'ChIJ1YlVbk6u0hIRjhFsUWwce2o', 'plus_code': {'compound_code': 'JW9H+79 Vergne, Narzole Cuneo, Italy', 'global_code': '8FP9JW9H+79'}, 'types': ['establishment', 'point_of_interest']}]
# A-Mano winery
# []
# ...

# %%
out_path = 'data/winery_latlon.csv'
latlong_df.to_csv(out_path)

# %%
#Join latlon with data
latlong_df = latlong_df[latlong_df['address']!='Italy']

# %%
latlong_df['name'] = latlong_df['name'].str[:-7]
# Out:
# C:\Users\geoffc.REDMOND\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
latlong_df.head()
# Out:
#                       name        lat       long  \
# 0          460 Casina Bric  44.618212   7.928460
# 1          Abbadia Ardenga  43.087302  11.544132
# 2    Abbazia Monte Oliveto  43.175771  11.544765
# 3  Abbazia Santa Anastasia  37.972501  14.084965
# 4     Abbazia di Novacella  46.742693  11.648464
#
#                                              address
# 0  Via Sorello, Cascina Bricco Fraz. Vergne 12060...
# 1        Via Romana, 139, 53024 Torrenieri SI, Italy
# 2    Monte Oliveto Maggiore, 53041 Asciano SI, Italy
# 3  Contrada Santa Anastasia, 90013 Castelbuono Pa...
# 4          Via Abbazia, 1, 39040 Novacella BZ, Italy

# %%
df_out = df.merge(right=latlong_df,how='left',left_on ='winery',right_on='name')

# %%
out_path = 'data/winemag-data-geocoded.csv'
df_out.to_csv(out_path)
#df_out.size
